# %%
import pandas as pd
from matplotlib import pyplot as plt
import os

# %%
# 读取CSV文件
df_y = pd.read_csv(r'第三章\3.1超表面数据集\wanzhengdB.csv', dtype=float, header=None, encoding='utf-8')
df_x = pd.read_csv(r'fre.csv', dtype=float, header=None, encoding='utf-8')

# %%
for index, row in df_y.iterrows():
    print(index)
    print(row)
    plt.plot(df_x.values.flatten(), row)
    break
# Out:
# 0
# 0      -0.045566
# 1      -0.045741
# 2      -0.045917
# 3      -0.046094
# 4      -0.046272
#           ...
# 996    -0.068709
# 997    -0.068610
# 998    -0.068511
# 999    -0.068413
# 1000   -0.068316
# Name: 0, Length: 1001, dtype: float64
